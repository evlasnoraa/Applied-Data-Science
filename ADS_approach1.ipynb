# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
import warnings

# %%
link = 'dft_traffic_counts_aadf.csv'
raw_df = pd.read_csv(link)

# %%
top_traf_2000 = raw_df.iloc[np.where(np.array(raw_df['year']) == 2000)[0]].nlargest(n=15, columns=['all_motor_vehicles'])
top_cp_2000 = list(top_traf_2000['count_point_id'])
top_cp_filtered = []
for i in top_cp_2000:
    if len(raw_df.iloc[np.where(np.array(raw_df['count_point_id']) == i)]) == 21:
        top_cp_filtered.append(i)
top_cp_filtered = top_cp_filtered[0:10]
top_cp_filtered
# Out:
# [46050, 47876, 7902, 73638, 27923, 48582, 37918, 73987, 73986, 57740]

# %%
years = list(np.linspace(2000, 2019, 20))
years = [int(a) for a in years]
amv_trend = {}
amv_trend['Years'] = years
for i in top_cp_filtered:
    listy = []
    #print(i)
    for j in years:
        #print(j)
        j_data = raw_df.iloc[np.where(np.array(raw_df['year']) == j)[0]]
        i_in_j = j_data.iloc[np.where(np.array(j_data['count_point_id']) == i)[0]]
        val = i_in_j.iloc[0, 32]
        listy.append(val)
    amv_trend[i] = listy

R_ana = pd.DataFrame.from_dict(amv_trend)

# %%
R_ana.plot(x='Years', y=top_cp_filtered, kind = 'line')
# Out:
# <AxesSubplot:xlabel='Years'>

# %%
for i in top_cp_filtered:
    autocorrelation_plot(R_ana[i])

# %%
R_ana
# Out:
#     Years   46050   47876    7902   73638   27923   48582   37918   73987  \
# 0    2000  186845  185325  184181  180058  180058  175138  173413  159984
# 1    2001  168507  194586  163790  169617  169617  140411  176859  185485
# 2    2002  171808  193528  179064  178329  178329  140319  153722  167634
# 3    2003  169068  196174  167224  164593  164593  134029  158171  158293
# 4    2004  175365  166634  157701  164417  164417  146106  164059  151760
# 5    2005  167341  166882  160320  164527  164527  144230  177019  149001
# 6    2006  168836  168722  150601  156545  156545  144512  173493  150060
# 7    2007  177982  200376  176092  183235  183235  150929  175559  182640
# 8    2008  174720  200548  175359  209977  209977  146055  171566  177023
# 9    2009  185991  192920  157767  213127  213127  152957  179749  172266
# 10   2010  184002  195360  177555  185633  185633  141194  176150  175351
# 11   2011  180839  195768  161599  172586  172586  147992  189048  159997
# ...

# %%
len(raw_df.iloc[np.where(np.array(raw_df['count_point_id']) == 48582)])
# Out:
# 21

# %%
def evaluate_arima_model(X, arima_order):
    # prepare training dataset
    train_size = int(len(X) * 0.75)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    error = mean_squared_error(test, predictions)
    return error
# Out:
# <ipython-input-9-0330d62c5a80>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
def evaluate_models(dataset, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                except:
                    continue
    return best_cfg, best_score

# %%
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
top_cp_orders = {}
for j in top_cp_filtered:
    warnings.filterwarnings("ignore")
    best_order, best_score = evaluate_models(list(R_ana[j]), p_values, d_values, q_values)
    top_cp_orders[j] = [best_order, best_score]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
future_years = list(np.linspace(2021, 2051, 30))
for j in top_cp_filtered:
    history = list(R_ana[j])
    predictions = list()
    for t in future_years:
        model = ARIMA(history, order=top_cp_orders[j][0])
        model_fit = model.fit()
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        history.append(yhat)
    plt.figure()
    plt.plot(history)
    plt.show
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
history = list(R_ana[46050])
predictions = list()
for t in future_years:
    model = ARIMA(history, order=top_cp_orders[46050][0])
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    history.append(yhat)
plt.figure()
plt.plot(predictions)
plt.show
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
top_cp_orders
# Out:
# {46050: [(6, 0, 0), 6244725.085755361],
#  47876: [(8, 0, 0), 151459019.72878444],
#  7902: [(0, 2, 1), 26772085.620262392],
#  73638: [(0, 0, 2), 982976954.7933222],
#  27923: [(1, 0, 0), 383043450.0741594],
#  48582: [(4, 0, 2), 56756494.4586526],
#  37918: [(4, 0, 1), 361009428.48910177],
#  73987: [(4, 1, 0), 71649103.4744676],
#  73986: [(4, 1, 0), 71649103.4744676],
#  57740: [(4, 1, 0), 71649103.4744676]}

# %%
import numpy as np
list(np.linspace(2020, 2051, 31))
# Out:
# [2020.0,
#  2021.0333333333333,
#  2022.0666666666666,
#  2023.1,
#  2024.1333333333334,
#  2025.1666666666667,
#  2026.2,
#  2027.2333333333333,
#  2028.2666666666667,
#  2029.3,
#  2030.3333333333333,
#  2031.3666666666666,
#  2032.4,
#  2033.4333333333334,
#  2034.4666666666667,
#  2035.5,
#  2036.5333333333333,
#  2037.5666666666666,
#  2038.6,
#  2039.6333333333334,
#  2040.6666666666667,
#  2041.7,
#  2042.7333333333333,
#  2043.7666666666667,
#  2044.8,
#  2045.8333333333333,
#  2046.8666666666666,
#  2047.9,
#  2048.9333333333334,
#  2049.9666666666667,
#  2051.0]

# %%
A = [1, 2, 3]
B = [3, 4, 5]
C = (np.array(A) * np.array(B))

# %%
C
# Out:
# array([ 3,  8, 15])
